# %% [markdown]
# <a href="https://colab.research.google.com/github/saraadastan/sara/blob/master/superbends.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Higher order effect of superbends**
#
# The higher order effect of superbends or normal dipoles come from different origion:
#
#
# *   First of all, it can come from the mechanism of the magnet.
# *    Second part it can be consider in simulation when we consider csbend.
#
#
# *   The third part which is come from the curvature from the change of the strength of the dipoles which doesn't have a hard edge shape.
# ![image.png](data:image/png;base64,...)
